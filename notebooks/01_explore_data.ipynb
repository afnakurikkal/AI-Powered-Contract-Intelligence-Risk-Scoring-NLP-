# %%
print("hello")
# Out:
# hello

# %%
import json

with open('../data/raw/CUADv1.json', 'r') as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import json
#       2
# ----> 3 with open('../data/raw/CUADv1.json', 'r') as f:
#       4     data = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/CUADv1.json'

# %%
import json

with open('../data/raw/cuad-main/data/CUADv1.json', 'r') as f:
    data = json.load(f)

# %%
print(len(data['data']))
print(data['data'][0]['title'])
# Out:
# 510
# LIMEENERGYCO_09_09_1999-EX-10-DISTRIBUTOR AGREEMENT
